# %%
import pandas as pd 




persone = [
   {
        'nome': 'Mario', # chiave: nome, valore: Marco
        'cognome': 'Ricci',
        'eta': 30,
        'citta': 'Milano',
        'codice_fiscale': 'MRI7894DH45O1P',
        'professione': 'Ingegnere'
    },
    {
        "nome": "Rudy",
        "cognome": "Botosso",
        "eta": 54,
        "citta": "Biella",
        "codice fiscale": "BTTRDY71L15A859E",
        "professione": "Informatico"
    },
    {
        "nome": "Marco",
        "cognome": "Secci",
        "eta": 54,
        "citta": "San Donà di Piave",
        "codice fiscale": "SCCMRC71P22H823A",
        "professione": "Disoccupato"
    },
    {
        'nome':'Andrea',
        'cognome':'Romano',
        'eta': 36,
        'citta': 'Ripatransone',
        'codice_fiscale': 'RNINFEINFIEN',
        'professione': 'Studente'
    },
    {
            'nome': 'Saverio', 
            'cognome': 'Carulli',
            'eta': 34,
            'citta': 'Spinazzola',
            'codice_fiscale': 'CRLSVR92H24O1P',
            'professione': 'Disoccupato'
    },
    {
        'nome': 'Giulia', 
        'cognome': 'Pierro',
        'eta': 25,
        'citta': 'Latina',
        'codice_fiscale': 'PRRGLI7894DH45O1P',
        'professione': 'Studente'
    },
    {
        'nome': 'Fabrice',
        'cognome': 'Cheick',
        'eta': 51,
        'citta': 'Ferrara',
        'codice_fiscale': 'CHKFRC75Z20H231G',      
        'professione': 'Pastore'
    },
    {
        'nome': 'Laura',
        'cognome': 'Ricordi',
        'eta': 33,
        'citta': 'Alessandria',
        'codicefiscale':  'chi lo sa?',
        'professione': 'speriamo hr data analyst'
    },
    {
        'nome': 'Luigia',
        'cognome': 'Valente',
        'eta': 32,
        'citta': 'Avellino',
        'codice_fiscale': 'VLNLGU93R64A783K',
        'professione': 'Receptionist'
    },
    {
        'nome': 'Teresa',
        'cognome': 'Balsamo',
        'eta': 25,
        'citta': 'Roma', 
        'codice_fiscale': 'BLSTRS00H48A024P',
        'professione': 'in_cerca'   
    }
]

df = pd.DataFrame(persone)
df.head(5)
# Out:
#       nome  cognome  eta              citta  codice_fiscale  professione  \
# 0    Mario    Ricci   30             Milano  MRI7894DH45O1P    Ingegnere
# 1     Rudy  Botosso   54             Biella             NaN  Informatico
# 2    Marco    Secci   54  San Donà di Piave             NaN  Disoccupato
# 3   Andrea   Romano   36       Ripatransone    RNINFEINFIEN     Studente
# 4  Saverio  Carulli   34         Spinazzola  CRLSVR92H24O1P  Disoccupato
#
#      codice fiscale codicefiscale
# 0               NaN           NaN
# 1  BTTRDY71L15A859E           NaN
# 2  SCCMRC71P22H823A           NaN
# 3               NaN           NaN
# 4               NaN           NaN

# %%
df.head(5) # mostra le prime 5 righe del dataframe
# Out:
#       nome  cognome  eta              citta  codice_fiscale  professione  \
# 0    Mario    Ricci   30             Milano  MRI7894DH45O1P    Ingegnere
# 1     Rudy  Botosso   54             Biella             NaN  Informatico
# 2    Marco    Secci   54  San Donà di Piave             NaN  Disoccupato
# 3   Andrea   Romano   36       Ripatransone    RNINFEINFIEN     Studente
# 4  Saverio  Carulli   34         Spinazzola  CRLSVR92H24O1P  Disoccupato
#
#      codice fiscale codicefiscale
# 0               NaN           NaN
# 1  BTTRDY71L15A859E           NaN
# 2  SCCMRC71P22H823A           NaN
# 3               NaN           NaN
# 4               NaN           NaN

# %%
# Creazione del dataframe(studenti) = dataset(tabella) 
studenti = {
    "nome": ["Mario", "Rudy", "Marco"],
    "cognome": ["Ricci", "Botosso", "Secci"],
    "eta": [30, 54, 54],
    "citta": ["Milano", "Biella", "San Donà di Piave"],
    "voto": [8, 9, 7]
}

# chiama pandas e crea un dataframe a partire dal dizionario studenti
df = pd.DataFrame(studenti)
df # stampa il dataframe(tipo tabella) con i dati degli studenti
# Out:
#     nome  cognome  eta              citta  voto
# 0  Mario    Ricci   30             Milano     8
# 1   Rudy  Botosso   54             Biella     9
# 2  Marco    Secci   54  San Donà di Piave     7

# %%
print(df) # stampa il dataframe(tipo tabella in formato csv)
# Out:
#     nome  cognome  eta              citta  voto
# 0  Mario    Ricci   30             Milano     8
# 1   Rudy  Botosso   54             Biella     9
# 2  Marco    Secci   54  San Donà di Piave     7

# %% [markdown]
# ### Stampa la prima riga della tabella

# %%
df.head(3) # mostra le prime 3 righe del dataframe sarebbe uguale fare select top 3 * from studenti
# Out:
#     nome  cognome  eta              citta  voto
# 0  Mario    Ricci   30             Milano     8
# 1   Rudy  Botosso   54             Biella     9
# 2  Marco    Secci   54  San Donà di Piave     7

# %% [markdown]
# <h4> La funzione <Strong>info()</Strong> restituisce l'infromazione del <i>DataFrame</i></h4>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      str
#  1   cognome  3 non-null      str
#  2   eta      3 non-null      int64
#  3   citta    3 non-null      str
#  4   voto     3 non-null      int64
# dtypes: int64(2), str(3)
# memory usage: 252.0 bytes

# %% [markdown]
# - describe() <strong>restituisce le statistiche descritive del <i>DataFrame</i></strong>
#
# | Definizione | Valore  |
# | ----------- | ------- |
# | count       | Conta   |
# | mean        | Media   |
# | min         | Minimo  |
# | max         | Massimo |

# %%
df.describe()
# Out:
#              eta  voto
# count   3.000000   3.0
# mean   46.000000   8.0
# std    13.856406   1.0
# min    30.000000   7.0
# 25%    42.000000   7.5
# 50%    54.000000   8.0
# 75%    54.000000   8.5
# max    54.000000   9.0

# %% [markdown]
# ##### <i>df['nome']</i> restituisce la lista dei nomi

# %%
df['nome']
# Out:
# 0      Mario
# 1       Rudy
# 2      Marco
# 3     Andrea
# 4    Saverio
# 5     Giulia
# 6    Fabrice
# 7      Laura
# 8     Luigia
# 9     Teresa
# Name: nome, dtype: str

# %% [markdown]
# Esercizio:
#
# - <i>Restituire la lista dei nomi e voti</i>

# %%
df[['nome', 'cognome', 'voto']]
# Out:
#     nome  cognome  voto
# 0  Mario    Ricci     8
# 1   Rudy  Botosso     9
# 2  Marco    Secci     7
